# %% [markdown]
# ## 인공지능(Artificial Intelligence)
#
# 1. 위키백과의 정의
#
#     * 인간의 학습능력, 추론능력, 지각능력등을 컴퓨터를 통해 구현하는 포괄적인 개념
#
#     * 지능(?)을 갖고 있는 기능을 갖춘 컴퓨터 시스템이며, 인간의 지능을 기계 등에 인공적으로 시연(구현)한 것이다.
#         *  또한 그와 같은 지능을 만들 수 있는 방법론이나 실현 가능성 등을 연구하는 과학 분야를 지칭하기도 한다
#
#
# 2. 인공지능의 유형
#
#     - Weak AI(ANI, Artificial Narrow Intelligence)
#         - Weak AI doesn’t mimic or replicate human intelligence, it merely __simulates
#           human behaviour based on a narrow range of parameters and contexts__.
#         - speech and language recognition of Siri, Alexa, etc & vision recognition of self-driving cars
#
#     - Strong AI (AGI, Artificial General Intelligence, Deep AI)
#         - With strong AI, machines can actually __think and carry out tasks on their own__, just like humans do.
#         - AlphaGo Zero
#
#     - Super AI(ASI, Artificial Superintelligence)
#         - the hypothetical AI that doesn’t just mimic or understand human intelligence and behaviou
#         - ASI is where __machines become self-aware and surpass the capacity of human intelligence and ability__.
#
#
# 3. AI의 역사
#
# <img src = "https://static.javatpoint.com/tutorial/ai/images/history-of-ai.png">
#
# <img src = "https://venturebeat.com/wp-content/uploads/2019/11/AI_promises.jpg?resize=1024%2C572&strip=all?strip=all">
#
#
# 4. A technological idyll or another winter?
#
# * 2016년도 예측: "2020년까지 1000만대의 자율 주행자가 도로에서 운행될 것."
#     * 2019년 봄: Ford CEO Jim Hackett "“We overestimated the arrival of autonomous vehicles.”
#     *TNot going to happen.
#     * The reason for the slow development is unanticipated complexity.
#
# * It’s unrealized or dashed promises that lead to AI winters.
# * An argument for winter is that all the advances so far have come from “narrow AI,” the ability of an algorithm to do one thing only, albeit with superhuman abilities.
# * Strong AI, also known as Artificial General Intelligence (AGI), does not yet exist. Surveys suggest it will be until 2060 before AGI exists, meaning that until then narrow AI algorithms will have to suffice.
#
# <img src="https://news.kbs.co.kr/data/fckeditor/new/image/2020/11/16/313731605528808913.png">
#
# ### Eventually, the use cases for narrow AI will be exhausted. Another AI winter will likely arrive, but it remains an open debate about when. If Microsoft president Brad Smith is right, winter won’t be coming soon. He recently predicted AI will transform society over the next three decades through to 2050.

# %% [markdown]
# ## AI vs ML vs DL
#
# - 기계학습(ML, Machine Learning): 데이터를 이용하여 명시적으로 정의되지 않은 패턴을 학습하여 미래 결과(값, 분포)를 예측
# - 심층학습(DL, Deep Learning): ML의 한 분야로 신경망(Neural Network)을 통하여 학습하는 알고리즘의 집합
#
#
# <img src="https://miro.medium.com/max/1050/1*Jf1NcBvaDH7fP0-QZp4XiA.png">
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/bb/AI-ML-DL.svg">

# %% [markdown]
# ## ML vs Traditional Programming
#
# ### 기존 프로그래밍의 접근방법
#
# <img src="https://www.logianalytics.com/wp-content/uploads/2019/03/Traditional-Programming.png">
#
# ### ML (with Supervised Learning) 의 접근방법
#
# <img src="https://www.logianalytics.com/wp-content/uploads/2019/03/Machine-Learning.png">
#
#
# __예__: 대출자(혹은 신용카드 이용자)의 재산, 소득, 기타 자료(입력 자료)와 연체(또는 미납) 통계 자료(출력자료) 에서 연체(신용불량) 예측 모형을 수립
#
#
#
# <img src = "https://www.logianalytics.com/wp-content/uploads/2019/03/Late-Payment-Model.png">
#
# * Machine learning can turn your business data into a financial asset. You can point the algorithm at your data so it can learn powerful rules that can be used to predict future outcomes.

# %% [markdown]
# ## [인공지능 적용사례 19가지](https://jameskim.online/ai-example19/)
#
# 1. TIK TOK (틱톡), 스노우 등 APP
# 2. 애를의 시리, 아마존의 알렉사, KT의 기가지니, 티맵의 아리아 등 음성인식 인공지능 비서
# 3. 자율주행 자동차(AGV, Automated Guided Vehicle) ‘웨이모’
# 4. 헬스케어 (feat. 코로나맵)
# 5. 인공지능 교육
# 6. 스마트홈
# 7. 스마트 그리드
# 8. 게임
# 9. 스마트 공장
# 10. 쇼핑 (추천알고리즘, AR탈의실, 아마존고)
# 11. 범죄예방
# 12. 챗봇 (쇼핑몰, A/S센터, 물류창고 등)
# 13. 스마트 농장
# 14. 인간의 친구, 인공지능 (SNS를 넘어서…)
# 15. 법률 (Legal Tech)
# 16. 인공지능 주방
# 17. 음악 창작
# 18. 사람처럼 행동하는 로봇 (휴머노이드 로봇)
# 19. 인공지능 반려견, 애견 분야
#
# ## [Top 41 Deep Learning Use Cases/Applications](https://research.aimultiple.com/deep-learning-applications/)
#
# 1. What are capabilities & technologies enabled by deep learning?
#     * Computer Vision
#         * Image classification and segmentation
#         * Object detection and tracking
#     * Natural language processing (NLP)
#         * AI smart assistants like Siri, Alexa
#         * Character recognition
#         * Voice recognition
#         * Semantics/Emotion Detection
#         * Real-time multi-language translation
#         * Chatbot
#     * Automated predictions: better, faster, cheaper, ...with the use of big data
#
#
# 2. What are deep learning use cases in different industries and sectors?
#     * Agriculture
#         * 센서와 위성으로부터의 데이터를 이용한 생산량 증대
#     * Aerospace & Defence
#         * 위성이미지를 통한 물체감지 및 확인
#         * 감시카메라를 통한 첩보활동 및 위험요인 탐지
#     * Automotive
#     * Financial services
#         * TradingBot
#         * 위험거래 예측
#         * 신용예측
#     * Healthcare
#         * 의학장비에서 나오는 이미지데이터를 활요한 질병예측
#     * Insurance
#         * 위장 사고 탐지
#     * Manufacturing
#         * 다양한 센서와 인공지능 학습을 가진 산업용 로봇
#         * 스마트 공장
#         * 사고 위험 사전 탐지
#         * 카메라와 물체탐지기술을 활용한 Quality Assurance/Control
#     * Pharmaceuticals & Medical Products
#         * 임상자료 및 관련 빅데이터를 이용한 신약 개발 및 부작용 예측
#     * Public sector
#         * 보안검사(Security Checks)를 위한 얼굴인식(Face Recognition)
#     * Retail & E-commerce
#         * 소비자 구매행태분석을 통한 수요예측 및 개인화된 추천시스템
#         * 사내 빅데이터를 위한 효율적 재고 관리
#         * Checkout이 없는무인쇼핑점("Just Walk Out" stores)
#         * Voice-enabled shopping and In-store robots 활용
#
#
# 3. What are deep learning use cases in different departments or functions?
#     * Analytics: DL을 이용한 각종 예측 모형 개발 및 활용
#     * Customer success: Chatbots
#     * Cybersecurity: 침입탐지 및 예방 시스템(IDS/IPS)
#     * Operations: 문서 인식을 통한 자동 데이터 추출
#     * Sales & Marketing: 개인화된 맞춤 광고, 잠재고객 확인, 위조 상품 탐지
#     * Supply Chain: 재고관리

# %% [markdown]
# ## 학습(Training) 결과물에 따른 모델 유형
#
# - Regression Model (회귀모형): 숫자 값(quantity)을 예측
# - Classification Model (분류 모형): 유한개의 클래스 (Class, Category)를 예측
#
# <img src="https://s3-ap-northeast-2.amazonaws.com/opentutorials-user-file/module/4916/12309.jpeg">

# %%
# 손실함수(MSE)의 변화를 시각화 하기위한 Utility function

import matplotlib.pyplot as plt

def plot1(data,label, title, xlabel, ylabel):
  plt.title(title)
  plt.xlabel(xlabel)
  plt.ylabel(ylabel)
  plt.plot(data, label=label)
  plt.legend(loc='best')
  plt.grid()
  plt.show()
    
def plot2(data1, label1, data2, label2, title, xlabel, ylabel):
  plt.title(title)
  plt.xlabel(xlabel)
  plt.ylabel(ylabel)
  plt.plot(data1, label=label1)
  plt.plot(data2, label=label2)  
  plt.legend(loc='best')
  plt.grid()
  plt.show()

# %% [markdown]
# ## 예제 1 (Simple Regession)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.optimizers import SGD
import numpy as np

# Step 1: 데이터 지정

x=np.array([1,2,3,4,5,6])
y=np.array([3,4,5,6,7,8]) # Notice y=x+2

# Step 2: 모델 구축
model=Sequential()                         
model.add(Dense(1,input_shape=(1,)))
        
# Step 3: 모델 콤파일

model.compile(optimizer=SGD(learning_rate=0.01),loss='mse')
model.summary() # 모델 구조 요약

# Step 4: 모델 학습
hist=model.fit(x,y,epochs=1000)

# weight와 bias 확인
# weights = model.layers[0].get_weights()[0]
# biases = model.layers[0].get_weights()[1]
# print('weights = {}\tbiases={}'.format(weights, biases))

# Step 5: 모델 평가 및 예측

input_x = np.array([-3.1,3.0,3.5, 15,20.1, 10000])
predicted=model.predict(input_x)
#print(result)
print('Predicted\tInput')

for i in range(len(predicted)):
    print(predicted[i],'\t',input_x[i]+2)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 1/1 [==============================] - 1s 632ms/step - loss: 4.0756
# Epoch 2/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2526
# Epoch 3/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4062
# Epoch 4/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0118
# Epoch 5/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8266
# Epoch 6/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7383
# Epoch 7/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6949
# Epoch 8/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6722
# Epoch 9/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6591
# Epoch 10/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6505
# Epoch 11/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6440
# Epoch 12/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6385
# Epoch 13/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6335
# Epoch 14/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6287
# Epoch 15/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6241
# Epoch 16/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6195
# Epoch 17/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6150
# Epoch 18/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6105
# Epoch 19/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6060
# Epoch 20/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6016
# Epoch 21/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5972
# Epoch 22/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5929
# Epoch 23/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5885
# Epoch 24/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5843
# Epoch 25/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5800
# Epoch 26/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5758
# Epoch 27/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5716
# Epoch 28/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5674
# Epoch 29/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5633
# Epoch 30/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5592
# Epoch 31/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5551
# Epoch 32/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5511
# Epoch 33/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5470
# Epoch 34/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5431
# Epoch 35/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5391
# Epoch 36/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5352
# Epoch 37/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5313
# Epoch 38/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5274
# Epoch 39/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5236
# Epoch 40/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5197
# Epoch 41/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5160
# Epoch 42/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5122
# Epoch 43/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5085
# Epoch 44/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5048
# Epoch 45/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5011
# Epoch 46/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4974
# Epoch 47/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4938
# Epoch 48/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4902
# Epoch 49/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4866
# Epoch 50/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4831
# Epoch 51/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4796
# Epoch 52/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4761
# Epoch 53/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4726
# Epoch 54/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.
1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0222
# Epoch 472/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0221
# Epoch 473/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0219
# Epoch 474/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0218
# Epoch 475/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0216
# Epoch 476/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0214
# Epoch 477/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0213
# Epoch 478/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0211
# Epoch 479/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0210
# Epoch 480/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0208
# Epoch 481/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0207
# Epoch 482/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0205
# Epoch 483/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0204
# Epoch 484/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0202
# Epoch 485/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0201
# Epoch 486/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0199
# Epoch 487/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0198
# Epoch 488/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0196
# Epoch 489/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0195
# Epoch 490/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0194
# Epoch 491/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0192
# Epoch 492/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0191
# Epoch 493/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0189
# Epoch 494/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0188
# Epoch 495/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0187
# Epoch 496/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0185
# Epoch 497/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0184
# Epoch 498/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0183
# Epoch 499/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0181
# Epoch 500/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0180
# Epoch 501/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0179
# Epoch 502/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0177
# Epoch 503/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0176
# Epoch 504/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0175
# Epoch 505/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0173
# Epoch 506/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0172
# Epoch 507/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0171
# Epoch 508/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0170
# Epoch 509/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0168
# Epoch 510/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0167
# Epoch 511/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0166
# Epoch 512/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0165
# Epoch 513/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0164
# Epoch 514/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0162
# Epoch 515/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0161
# Epoch 516/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0160
# Epoch 517/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0159
# Epoch 518/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0158
# Epoch 519/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0157
# Epoch 520/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0155
# Epoch 521/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0154
# Epoch 522/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 523/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0152
# Epoch 524/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0151
# Epoch 525/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 526/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0149
# Epoch 527/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0148
# Epoch 528/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0147
# Epoch 529/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0146
# Epoch 530/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0144
# Epoch 531/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0143
# Epoch 532/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0142
# Epoch 533/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0141
# Epoch 534/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0140
# Epoch 535/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 536/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 537/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 538/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 539/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 540/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 541/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0133
# Epoch 542/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0132
# Epoch 543/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0131
# Epoch 544/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 545/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 546/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 547/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0128
# Epoch 548/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 549/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 550/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 551/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0124
# Epoch 552/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0123
# Epoch 553/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 554/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0121
# Epoch 555/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0120
# Epoch 556/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 557/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 558/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0118
# Epoch 559/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 560/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0116
# Epoch 561/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 562/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0114
# Epoch 563/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 564/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 565/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0112
# Epoch 566/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0111
# Epoch 567/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0110
# Epoch 568/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 569/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 570/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0108
# Epoch 571/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0107
# Epoch 572/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0106
# Epoch 573/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0105
# Epoch 574/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0105
# Epoch 575/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 576/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0103
# Epoch 577/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0102
# Epoch 578/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0102
# Epoch 579/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0101
# Epoch 580/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0100
# Epoch 581/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0099
# Epoch 582/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0099
# Epoch 583/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0098
# Epoch 584/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 585/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 586/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0096
# Epoch 587/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0095
# Epoch 588/1000
# ...
# Epoch 811/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 812/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 813/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 814/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 815/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 816/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 817/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 818/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 819/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 820/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 821/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 822/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 823/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 824/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 825/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 826/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 827/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 828/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 829/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 830/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 831/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 832/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 833/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 834/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 835/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 836/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 837/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 838/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 839/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 840/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 841/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 842/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 843/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 844/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 845/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 846/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 847/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 848/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 849/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 850/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 851/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 852/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 853/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 854/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 855/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 856/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 857/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 858/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 859/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 860/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 861/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 862/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 863/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 864/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 865/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 866/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 867/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 868/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 869/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 870/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 871/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 872/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 873/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 874/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 875/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 876/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 877/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 878/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 879/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 880/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 881/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 882/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 883/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 884/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 885/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 886/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 887/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 888/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 889/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 890/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 891/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 892/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 893/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 894/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 895/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 896/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.9409e-04
# Epoch 897/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.8684e-04
# Epoch 898/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.7965e-04
# Epoch 899/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.7252e-04
# Epoch 900/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.6543e-04
# Epoch 901/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.5840e-04
# Epoch 902/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.5142e-04
# Epoch 903/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.4448e-04
# Epoch 904/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.3761e-04
# Epoch 905/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 9.3077e-04
# Epoch 906/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.2399e-04
# Epoch 907/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.1726e-04
# Epoch 908/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.1057e-04
# Epoch 909/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9
1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6469e-04
# Predicted	Input
# [-1.1844153] 	 -1.1
# [4.9853477] 	 5.0
# [5.491066] 	 5.5
# [17.122587] 	 17.0
# [22.280914] 	 22.1
# [10116.317] 	 10002.0

# %%
# 손실함수 시각화

plot1(hist.history['loss'], 'train loss', 'Loss','epochs','Loss')

# %% [markdown]
# ## 예제 2 (Multiple Regression)

# %%
from tensorflow.keras.optimizers import SGD, Adam

# Step 1:데이터 생성
x=np.array([ [1,2,0],[5,4,3],[1,2,-1], [3,1,0],[2,4,2],
             [4,1,2],[-1,3,2],[4,3,3],[0,2,6],[2,2,1],
             [1,-2,-2],[0,1,3],[1,1,3],[0,1,4],[2,3,3] ])
y=np.array([-4,4,-6,3,-4,
             9,-7,5,6,0,
             4,3,5,5,1]) 
# Notice y = 2 x1 - 3 x2 +  2x3
# from_y = [2*data[0]-3*data[1]+2*data[2] for data in x]
# print('from_y: ', from_y)
# print('x shape: ', x.shape, ', y shape: ', y.shape)

# Step 2:모델 구축

model=Sequential()
Dense(hidden_units, activation = 'relu',input_dim= input_size),

model.add(Dense(1,input_shape=(3,),activation ='linear'))

# Step 3:모델 콤파일

model.compile(optimizer=SGD(learning_rate=1e-2), loss='mse')

model.summary()

# Step 4:모델 학습

hist = model.fit(x,y, epochs=1000)

# weight와 bias 확인
weights = model.layers[0].get_weights()[0]
biases = model.layers[0].get_weights()[1]
print('weights = {}\tbiases={}'.format(weights, biases))


# Step 5:모델 평가 및 예측

test_data=[ [5,5,0],[2,3,1],[-1,0,-1],[10,5,2],[4,-1,-2] ]      
true_y = [2*data[0]-3*data[1]+2*data[2] for data in test_data]
predicted_y = model.predict(np.array(test_data))

print('Predicted y\tTrue y')

for i in range(len(predicted_y)):
    print(predicted_y[i],'\t',true_y[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3e402035c4a6> in <module>
#      16
#      17 model=Sequential()
# ---> 18 Dense(hidden_units, activation = 'relu',input_dim= input_size),
#      19
#      20 model.add(Dense(1,input_shape=(3,),activation ='linear'))
#
# NameError: name 'hidden_units' is not defined

# %%
# Loss 시각화 
plot1(hist.history['loss'], 'train loss', 'Loss','epochs','Loss')

# %% [markdown]
# ### MNIST Dataset
#
# MNIST is a simple computer vision dataset. It consists of images of handwritten digits like these:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/27/MnistExamples.png/480px-MnistExamples.png">
#
# - 60,000 images of handwritten digits for training data (mnist.train),
# - 10,000 images of handwritten digits for test data (mnist.test),
# - Each image is 28 pixels by 28 pixels. We can interpret this as a big array of numbers:
#
# <img src="https://www.tensorflow.org/images/MNIST-Matrix.png">

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# mnist data 로딩

(X_train, Y_train),(X_test, Y_test) = mnist.load_data()

# Original 데이터 확인
print('X_train shape: {}\tY_train shape: {}\n'.format(X_train.shape, Y_train.shape))
print('X_test shape: {}\tY_test shape: {}\n'.format(X_test.shape, Y_test.shape))

np.set_printoptions(linewidth=600, precision=2) # linewidth = 라인 최대 글자수, precision: 소수점이하 자리수

# Browsing Original Dataset

print('\n',Y_train[0: 9])
print('\n',X_train[0])
print('\n',X_train[5])

# %%
fig = plt.figure(figsize=(6,6)) # Width, height in inches.
fig.subplots_adjust(hspace=0.7)

for index in range(25):
    plt.subplot(5,5, index+1) # 5행 5열
    plt.imshow(X_train[index], cmap='gray')
    plt.axis('off')
    plt.title(str(Y_train[index]))
    
plt.show()

plt.imshow(X_train[9], cmap='gray') 
plt.colorbar()   
plt.show()

# %%
import time
start = time.time() # 실행시간 측정을 위해 시작 시간 저장 

# Step 1: 데이터 준비. 전처리 가공, 하이퍼파라미터 지정

(X_train, Y_train),(X_test, Y_test) = mnist.load_data()
image_size = X_train.shape[1]
num_classes = 10
input_size= image_size*image_size 

# 데이터 전처리:

# 1) Dense Layers의 input은 1차원 텐서만 가능
X_train = np.reshape(X_train, [-1,input_size])
X_test = np.reshape(X_test,[-1,input_size])
print('X_train shape: ', X_train.shape)

# 2) Data normalization: # 학습을 더 빨리하고 Local optimum 에 빠지는 가능성을 감소
X_train = X_train/255.0
X_test = X_test/255.0

# 3) One-hot encoding
# The Y_train data is the associated labels for all the x_train examples. Rather
# than storing the label as an integer, it should be stored as a 1x10 binary 
# array with the one representing the digit. This is known as __one-hot encoding__. 
Y_train = to_categorical(Y_train, num_classes=num_classes)
Y_test = to_categorical(Y_test, num_classes=num_classes)

# 하이퍼 파라미터 설정
# In computer programming it is generally best to use variables and constants 
# rather than having to hard-code specific numbers every time that number is used. 
epochs = 20
batch_size = 128
hidden_units = 32

# Step 2: 모델 구성 
model = Sequential([
                    Dense(hidden_units, activation = 'relu',input_dim= input_size),
                    Dense(10, activation='softmax')
 ])
 
# Step 3: 모델 컴파일
model.compile(optimizer='rmsprop', 
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# Step 4: 모델 학습
hist = model.fit(X_train, Y_train, epochs=epochs, 
                 batch_size=batch_size,  validation_split=0.3, verbose = 1)
            # verbose = 0 (silent), 1 (progress bar), 2 (one line per epoch)
            # default = 1

# Loss와 Accuracy 시각화 
plot2(hist.history['loss'],  'train loss',hist.history['val_loss'],'validation loss', 'Loss','epochs','loss')
plot2(hist.history['accuracy'], 'train accuracy', hist.history['val_accuracy'],'validation accuracy', 'Accuracy','epochs','accuracy')

# Step 5: 모델 평가
model.evaluate(X_test, Y_test, batch_size= batch_size) 

print('\nExecution time in seconds:', time.time()-start) #  실행시간 출력

# %%
# Check Confusion Matrix

from sklearn.metrics import confusion_matrix
import seaborn as sns

plt.figure(figsize=(6,6))

predicted_value=model.predict(X_test)

cm=confusion_matrix(np.argmax(Y_test, axis=-1),
                   np.argmax(predicted_value, axis=-1))
sns.heatmap(cm,annot=True, fmt='d')

plt.show()

# Check accuracies among 10 groups

print(cm)
print('\n')

for i in range(10):
    print(('label = %d\t(%d/%d)\taccuracy = %.3f') % 
          (i, np.max(cm[i]), np.sum(cm[i]), 
           np.max(cm[i])/np.sum(cm[i])))
    
# Test Data에서의 숫자별 정확도 확인

label_distribution = np.zeros(10)
prediction_distribution = np.zeros(10)

for idx in range(len(Y_test)):

    label = int(np.argmax(Y_test[idx]))

    label_distribution[label] = label_distribution[label] + 1

    prediction = int(np.argmax(predicted_value[idx]))

    prediction_distribution[prediction] = prediction_distribution[prediction] + 1


print(label_distribution)
print(prediction_distribution)

# %%
images_label5 = []
for i in range(10000):
  if (np.argmax(Y_test[i]) == 5) and (np.argmax(predicted_value[i]) != 5):
    images_label5.append(X_test[i])

number_images = len(images_label5)

for i in range(number_images):
    plt.imshow(np.reshape(images_label5[i], [28,28]), cmap='gray') 
    plt.colorbar()   
    plt.axis('off')
    plt.show()
